# %%
from google.colab import drive
drive.mount('/content/drive/')  # 将google硬盘挂载在/comtent/drive/目录上面
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
! cp -r /content/drive/'My Drive'/facedect.zip .
! unzip facedect.zip
! cp -r /content/drive/'My Drive'/facedect/* .
# Out:
# Archive:  facedect.zip
#    creating: data/
#   inflating: data.py
#    creating: data/I/
#    creating: data/II/
#   inflating: data/II/003932.jpg
#   inflating: data/II/003935.jpg
#   inflating: data/II/003976.jpg
#   inflating: data/II/003980.jpg
#   inflating: data/II/003988.jpg
#   inflating: data/II/004002.jpg
#   inflating: data/II/004009.jpg
#   inflating: data/II/004031.jpg
#   inflating: data/II/004037.jpg
#   inflating: data/II/004061.jpg
#   inflating: data/II/004085.jpg
#   inflating: data/II/004086.jpg
#   inflating: data/II/004103.jpg
#   inflating: data/II/004107.jpg
#   inflating: data/II/004119.jpg
#   inflating: data/II/004179.jpg
#   inflating: data/II/004199.jpg
#   inflating: data/II/004227.jpg
#   inflating: data/II/004229.jpg
#   inflating: data/II/004241.jpg
#   inflating: data/II/004252.jpg
#   inflating: data/II/004271.jpg
#   inflating: data/II/004273.jpg
#   inflating: data/II/004287.jpg
#   inflating: data/II/004295.jpg
#   inflating: data/II/004312.jpg
# ...

# %%
! cp -r /content/drive/'My Drive'/facedect/* .

# %%
# !python mydector.py --seed 9922 --save-model --save-directory /content/drive/'My Drive'/checkpoints/defaultNet_Adam2xLR --alg adam --lr 0.002 --epochs 505
# Out:
# Namespace(alg='adam', angle=30, batch_size=64, checkpoint='', epochs=505, log_interval=10, loss='L2', lr=0.002, momentum=0.5, net='', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/defaultNet_Adam2xLR', save_interval=20, save_model=True, scheduler='', seed=9922, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 3437.905762
# Train Epoch: 1 [640/2228 (29%)]	 pts_loss: 1701.058228
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 902.112061
# Train Epoch: 1 [1920/2228 (86%)]	 pts_loss: 560.564636
# Valid: pts_loss: 352.719950
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 476.565613
# Train Epoch: 2 [640/2228 (29%)]	 pts_loss: 355.861084
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 343.175323
# Train Epoch: 2 [1920/2228 (86%)]	 pts_loss: 337.624390
# Valid: pts_loss: 326.710561
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 355.466187
# ...

# %%
! cp /content/drive/'My Drive'/checkpoints/defaultNet_Adam2xLR/detector_epoch_500.pt .

# %%
# !python mydector.py --seed 999322 --save-model --save-directory /content/drive/'My Drive'/checkpoints/defaultNet_Adam2xLR_500_1000 --checkpoint detector_epoch_500.pt --alg adam --lr 0.002 --epochs 501
# Out:
# Namespace(alg='adam', angle=30, batch_size=64, checkpoint='detector_epoch_500.pt', epochs=501, log_interval=10, loss='L2', lr=0.002, momentum=0.5, net='', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/defaultNet_Adam2xLR_500_1000', save_interval=20, save_model=True, scheduler='', seed=999322, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_500.pt
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 62.650059
# Train Epoch: 1 [640/2228 (29%)]	 pts_loss: 80.523064
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 63.299152
# Train Epoch: 1 [1920/2228 (86%)]	 pts_loss: 66.208328
# Valid: pts_loss: 210.987522
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 53.741821
# Train Epoch: 2 [640/2228 (29%)]	 pts_loss: 42.089191
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 46.106373
# Train Epoch: 2 [1920/2228 (86%)]	 pts_loss: 86.669205
# Valid: pts_loss: 213.435984
# ...

# %%
! cp /content/drive/'My Drive'/checkpoints/defaultNet90_180/detector_epoch_90.pt .

# %%
# !python mydector.py --seed 99522 --save-model --save-directory /content/drive/'My Drive'/checkpoints/defaultNet_Adam2xLR500_1000 --checkpoint detector_epoch_500.pt --alg adam --lr 0.001 --epochs 01
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2416: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# torch.Size([1, 256, 150, 225])
# torch.Size([1, 256, 75, 113])
# torch.Size([1, 256, 38, 57])
# torch.Size([1, 256, 19, 29])
# ...
