# %%
from google.colab import drive
drive.mount('/content/drive/')  # 将google硬盘挂载在/comtent/drive/目录上面

# %%
! cp -r /content/drive/'My Drive'/facedect.zip .
! unzip facedect.zip
! cp -r /content/drive/'My Drive'/facedect/* .
# Out:
# Archive:  facedect.zip
#    creating: data/
#   inflating: data.py
#    creating: data/I/
#    creating: data/II/
#   inflating: data/II/003932.jpg
#   inflating: data/II/003935.jpg
#   inflating: data/II/003976.jpg
#   inflating: data/II/003980.jpg
#   inflating: data/II/003988.jpg
#   inflating: data/II/004002.jpg
#   inflating: data/II/004009.jpg
#   inflating: data/II/004031.jpg
#   inflating: data/II/004037.jpg
#   inflating: data/II/004061.jpg
#   inflating: data/II/004085.jpg
#   inflating: data/II/004086.jpg
#   inflating: data/II/004103.jpg
#   inflating: data/II/004107.jpg
#   inflating: data/II/004119.jpg
#   inflating: data/II/004179.jpg
#   inflating: data/II/004199.jpg
#   inflating: data/II/004227.jpg
#   inflating: data/II/004229.jpg
#   inflating: data/II/004241.jpg
#   inflating: data/II/004252.jpg
#   inflating: data/II/004271.jpg
#   inflating: data/II/004273.jpg
#   inflating: data/II/004287.jpg
#   inflating: data/II/004295.jpg
#   inflating: data/II/004312.jpg
# ...

# %%
! cp -r /content/drive/'My Drive'/facedect/* .

# %%
# !python mydector.py --seed 9922 --save-model --save-directory /content/drive/'My Drive'/checkpoints/trained_resnet50_adam_lr --batch-size 128 --alg adam --net resnet50 --lr 0.002 --epochs 202
# Out:
# Namespace(alg='adam', angle=30, batch_size=128, checkpoint='', epochs=202, log_interval=10, loss='L2', lr=0.002, momentum=0.5, net='resnet50', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/trained_resnet50_adam_lr', save_interval=20, save_model=True, scheduler='', seed=9922, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 13749.579102
# Train Epoch: 1 [1280/2228 (56%)]	 pts_loss: 2361.183105
# Valid: pts_loss: 1858.793837
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 1566.478271
# Train Epoch: 2 [1280/2228 (56%)]	 pts_loss: 1416.267334
# Valid: pts_loss: 1233.999946
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 1383.009277
# Train Epoch: 3 [1280/2228 (56%)]	 pts_loss: 1349.375854
# Valid: pts_loss: 1247.574639
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 1386.644043
# Train Epoch: 4 [1280/2228 (56%)]	 pts_loss: 1339.210205
# Valid: pts_loss: 1390.914252
# ...

# %%
! cp /content/drive/'My Drive'/checkpoints/trained_resnet50_adam_lr/detector_epoch_200.pt .

# %%
# !python mydector.py --seed 99922 --save-model --save-directory /content/drive/'My Drive'/checkpoints/trained_resnet50_adam_lr200-700 --batch-size 128 --alg adam --net resnet50 --lr 0.002 --epochs 502 --checkpoint detector_epoch_200.pt
# Out:
# Namespace(alg='adam', angle=30, batch_size=128, checkpoint='detector_epoch_200.pt', epochs=502, log_interval=10, loss='L2', lr=0.002, momentum=0.5, net='resnet50', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/trained_resnet50_adam_lr200-700', save_interval=20, save_model=True, scheduler='', seed=99922, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_200.pt
# Traceback (most recent call last):
#   File "mydector.py", line 241, in <module>
#     print(main_test())
#   File "mydector.py", line 217, in main_test
#     train(args, train_loader, valid_loader, model, criterion_pts, optimizer, device)
#   File "mydector.py", line 50, in train
#     output_pts = model(input_img)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
# ...

# %%
# !ls drive/'My Drive'/checkpoints/
# Out:
# ls: cannot access 'drive/My Drive/checkpoint/': Not a directory

# %%
! cp /content/drive/'My Drive'/checkpoints/10000trained_restnet18/detector_epoch_299.pt .
# !python mydector.py --seed 6199522 --save-model --save-directory /content/drive/'My Drive'/checkpoints/299_10000trained_restnet18_w_rotation --net resnet18 --lr 0.001 --checkpoint detector_epoch_299.pt --epoch 10000
# Out:
# Namespace(alg='SGD', angle=30, batch_size=64, checkpoint='detector_epoch_299.pt', epochs=10000, log_interval=20, lr=0.001, momentum=0.5, net='resnet18', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/299_10000trained_restnet18_w_rotation', save_model=True, seed=6199522, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_299.pt
# Train Epoch: 0 [0/2228 (0%)]	 pts_loss: 2657.366455
# Train Epoch: 0 [1280/2228 (57%)]	 pts_loss: 755.443054
# Valid: pts_loss: 889.133518
# ...
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 656.369995
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 680.705444
# Valid: pts_loss: 624.442874
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 484.670898
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 628.336121
# Valid: pts_loss: 667.158264
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 597.620728
# ...
