# %%
from google.colab import drive
drive.mount('/content/drive/')  # 将google硬盘挂载在/comtent/drive/目录上面
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
! cp -r /content/drive/'My Drive'/facedect.zip .
! unzip facedect.zip
! cp -r /content/drive/'My Drive'/facedect/* .
# Out:
# Archive:  facedect.zip
# replace data.py? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
! cp -r /content/drive/'My Drive'/facedect/* .

# %%
# !cp /content/drive/'My Drive'/checkpoint/detector_epoch_99.pt .

# %%
# !python mydector.py --seed 99122 --save-model --save-directory trained_resnet152 --net resnet152
! cp -r trained_resnet152 /content/drive/'My Drive'/checkpoint
# Out:
# Namespace(batch_size=64, checkpoint='', epochs=100, log_interval=20, lr=0.001, momentum=0.5, net='resnet152', no_cuda=False, phase='Train', save_directory='trained_resnet152', save_model=True, seed=99122, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Train Epoch: 0 [0/2228 (0%)]	 pts_loss: 11881.422852
# Train Epoch: 0 [1280/2228 (57%)]	 pts_loss: 2365.030029
# Valid: pts_loss: 1594.519864
# ...
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 305.477417
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 211.726517
# Valid: pts_loss: 169.475254
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 191.638519
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 181.381638
# Valid: pts_loss: 231.724250
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 250.748703
# Train Epoch: 3 [1280/2228 (57%)]	 pts_loss: 237.672302
# Valid: pts_loss: 171.890124
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 92.776390
# Train Epoch: 4 [1280/2228 (57%)]	 pts_loss: 120.473045
# Valid: pts_loss: 201.803616
# ...

# %%
# !python mydector.py --seed 99122 --save-model --save-directory trained_resnet152 --net resnet152 --checkpoint detector_epoch_99.pt
! cp -r trained_resnet152/detector_epoch_99.pt /content/drive/'My Drive'/checkpoint
# Out:
# Namespace(batch_size=64, checkpoint='detector_epoch_99.pt', epochs=100, log_interval=20, lr=0.001, momentum=0.5, net='resnet152', no_cuda=False, phase='Train', roi=0.25, save_directory='trained_resnet152', save_model=True, seed=99122, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Train Epoch: 0 [0/2228 (0%)]	 pts_loss: 2002.863892
# Train Epoch: 0 [1280/2228 (57%)]	 pts_loss: 908.164001
# Valid: pts_loss: 962.022359
# ...
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 888.099731
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 917.271606
# Valid: pts_loss: 941.599508
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 993.496460
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 972.638489
# Valid: pts_loss: 946.167358
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 907.898987
# Train Epoch: 3 [1280/2228 (57%)]	 pts_loss: 888.120911
# Valid: pts_loss: 962.237895
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 1010.558167
# Train Epoch: 4 [1280/2228 (57%)]	 pts_loss: 925.374451
# ...

# %%
! cp /content/drive/'My Drive'/checkpoint/detector_epoch_99.pt .
! rm -rf trained_models
! python mydector.py --seed 9912221 --save-model --save-directory trained_resnet152 --net resnet152 --checkpoint detector_epoch_99.pt --epoch 10000
! cp trained_resnet152/detector_epoch_699.pt /content/drive/'My Drive'/checkpoint
# Out:
# Namespace(batch_size=64, checkpoint='detector_epoch_99.pt', epochs=10000, log_interval=20, lr=0.001, momentum=0.5, net='resnet152', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='trained_resnet152', save_model=True, seed=9912221, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_99.pt
# Train Epoch: 0 [0/2228 (0%)]	 pts_loss: 853.394470
# Train Epoch: 0 [1280/2228 (57%)]	 pts_loss: 969.037048
# Valid: pts_loss: 915.904371
# ...
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 879.817383
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 855.499084
# Valid: pts_loss: 904.887153
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 883.170654
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 931.330933
# Valid: pts_loss: 895.510410
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 895.062439
# Train Epoch: 3 [1280/2228 (57%)]	 pts_loss: 816.873352
# Valid: pts_loss: 889.982205
# ...

# %%
! cp /content/drive/'My Drive'/checkpoint/ResNet152/detector_epoch_99_old.pt .
! rm -rf trained_models
! python mydector.py --seed 99121 --save-model --save-directory /content/drive/'My Drive'/checkpoint/10000trained_resnet152 --net resnet152 --checkpoint detector_epoch_99_old.pt --epoch 10000
# Out:
# Namespace(batch_size=64, checkpoint='detector_epoch_99_old.pt', epochs=10000, log_interval=20, lr=0.001, momentum=0.5, net='resnet152', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoint/10000trained_resnet152', save_model=True, seed=99121, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_99_old.pt
# Traceback (most recent call last):
#   File "mydector.py", line 191, in <module>
#     main_test()
#   File "mydector.py", line 176, in main_test
#     train(args, train_loader, valid_loader, model, criterion_pts, optimizer, device)
#   File "mydector.py", line 49, in train
#     output_pts = model(input_img)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/myNN.py", line 279, in forward
#     return self._forward_impl(x)
# ...
