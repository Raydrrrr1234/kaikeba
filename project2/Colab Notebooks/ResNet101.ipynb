# %%
from google.colab import drive
drive.mount('/content/drive/')  # 将google硬盘挂载在/comtent/drive/目录上面
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
! cp -r /content/drive/'My Drive'/facedect.zip .
! unzip facedect.zip
! cp -r /content/drive/'My Drive'/facedect/* .
# Out:
# Archive:  facedect.zip
#    creating: data/
#   inflating: data.py
#    creating: data/I/
#    creating: data/II/
#   inflating: data/II/003932.jpg
#   inflating: data/II/003935.jpg
#   inflating: data/II/003976.jpg
#   inflating: data/II/003980.jpg
#   inflating: data/II/003988.jpg
#   inflating: data/II/004002.jpg
#   inflating: data/II/004009.jpg
#   inflating: data/II/004031.jpg
#   inflating: data/II/004037.jpg
#   inflating: data/II/004061.jpg
#   inflating: data/II/004085.jpg
#   inflating: data/II/004086.jpg
#   inflating: data/II/004103.jpg
#   inflating: data/II/004107.jpg
#   inflating: data/II/004119.jpg
#   inflating: data/II/004179.jpg
#   inflating: data/II/004199.jpg
#   inflating: data/II/004227.jpg
#   inflating: data/II/004229.jpg
#   inflating: data/II/004241.jpg
#   inflating: data/II/004252.jpg
#   inflating: data/II/004271.jpg
#   inflating: data/II/004273.jpg
#   inflating: data/II/004287.jpg
#   inflating: data/II/004295.jpg
#   inflating: data/II/004312.jpg
# ...

# %%
! cp -r /content/drive/'My Drive'/facedect/* .

# %%
! rm -rf trained_models
! python mydector.py --seed 92221 --save-model --save-directory /content/drive/'My Drive'/checkpoints/10000trained_resnet101 --net resnet101 --epoch 10000 --lr 0.001
# Out:
# Namespace(batch_size=64, checkpoint='', epochs=10000, log_interval=20, lr=0.001, momentum=0.5, net='resnet101', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/10000trained_resnet101', save_model=True, seed=92221, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Train Epoch: 0 [0/2228 (0%)]	 pts_loss: 11671.984375
# Train Epoch: 0 [1280/2228 (57%)]	 pts_loss: 3319.206055
# Valid: pts_loss: 1505.280633
# ...
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 551.706299
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 560.206848
# Valid: pts_loss: 540.970652
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 529.368774
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 506.781525
# Valid: pts_loss: 564.092428
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 609.021912
# Train Epoch: 3 [1280/2228 (57%)]	 pts_loss: 634.258667
# Valid: pts_loss: 544.604292
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 536.655212
# ...

# %%
! cp /content/drive/'My Drive'/checkpoints/10000trained_resnet101/detector_epoch_299.pt .
! rm -rf trained_models
! python mydector.py --seed 92221 --save-model --save-directory /content/drive/'My Drive'/checkpoints/299_10000trained_resnet101 --net resnet101 --epoch 10000 --lr 0.001 --checkpoint detector_epoch_299.pt
# Out:
# Namespace(alg='SGD', angle=30, batch_size=64, checkpoint='detector_epoch_299.pt', epochs=10000, log_interval=20, lr=0.001, momentum=0.5, net='resnet101', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/299_10000trained_resnet101', save_model=True, seed=92221, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Traceback (most recent call last):
#   File "mydector.py", line 198, in <module>
#     main_test()
#   File "mydector.py", line 183, in main_test
#     train(args, train_loader, valid_loader, model, criterion_pts, optimizer, device)
#   File "mydector.py", line 20, in train
#     model.load_state_dict(torch.load(args.checkpoint))
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 529, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
# ...
