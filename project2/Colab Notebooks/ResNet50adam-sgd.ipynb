# %%
from google.colab import drive
drive.mount('/content/drive/')  # 将google硬盘挂载在/comtent/drive/目录上面
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
! cp -r /content/drive/'My Drive'/facedect.zip .
! unzip facedect.zip
! cp -r /content/drive/'My Drive'/facedect/* .
# Out:
# Archive:  facedect.zip
#    creating: data/
#   inflating: data.py
#    creating: data/I/
#    creating: data/II/
#   inflating: data/II/003932.jpg
#   inflating: data/II/003935.jpg
#   inflating: data/II/003976.jpg
#   inflating: data/II/003980.jpg
#   inflating: data/II/003988.jpg
#   inflating: data/II/004002.jpg
#   inflating: data/II/004009.jpg
#   inflating: data/II/004031.jpg
#   inflating: data/II/004037.jpg
#   inflating: data/II/004061.jpg
#   inflating: data/II/004085.jpg
#   inflating: data/II/004086.jpg
#   inflating: data/II/004103.jpg
#   inflating: data/II/004107.jpg
#   inflating: data/II/004119.jpg
#   inflating: data/II/004179.jpg
#   inflating: data/II/004199.jpg
#   inflating: data/II/004227.jpg
#   inflating: data/II/004229.jpg
#   inflating: data/II/004241.jpg
#   inflating: data/II/004252.jpg
#   inflating: data/II/004271.jpg
#   inflating: data/II/004273.jpg
#   inflating: data/II/004287.jpg
#   inflating: data/II/004295.jpg
#   inflating: data/II/004312.jpg
# ...

# %%
! cp -r /content/drive/'My Drive'/facedect/* .

# %%
# !python mydector.py --seed 9922 --save-model --save-directory /content/drive/'My Drive'/checkpoints/trained_resnet50_adam --batch-size 128 --alg adam --net resnet50 --lr 0.001 --epochs 202
# Out:
# Namespace(alg='adam', angle=30, batch_size=128, checkpoint='', epochs=202, log_interval=10, loss='L2', lr=0.001, momentum=0.5, net='resnet50', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/trained_resnet50_adam', save_interval=20, save_model=True, scheduler='', seed=9922, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 13878.601562
# Train Epoch: 1 [1280/2228 (56%)]	 pts_loss: 6707.353027
# Valid: pts_loss: 2613.562798
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 2775.683838
# Train Epoch: 2 [1280/2228 (56%)]	 pts_loss: 1478.023438
# Valid: pts_loss: 1330.066610
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 1463.319458
# Train Epoch: 3 [1280/2228 (56%)]	 pts_loss: 1355.368164
# Valid: pts_loss: 1277.291016
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 1377.151733
# Train Epoch: 4 [1280/2228 (56%)]	 pts_loss: 1351.881592
# Valid: pts_loss: 1230.812703
# ...

# %%
! cp /content/drive/'My Drive'/checkpoints/trained_resnet50_adam/detector_epoch_200.pt .

# %%
# !python mydector.py --seed 9922 --save-model --save-directory /content/drive/'My Drive'/checkpoints/trained_resnet50_adam_sgd --batch-size 128 --alg SGD --net resnet50 --lr 0.0001 --epochs 101 --checkpoint detector_epoch_200.pt
# Out:
# Namespace(alg='SGD', angle=30, batch_size=128, checkpoint='detector_epoch_200.pt', epochs=101, log_interval=10, loss='L2', lr=0.0001, momentum=0.5, net='resnet50', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/trained_resnet50_adam_sgd', save_interval=20, save_model=True, scheduler='', seed=9922, test_batch_size=64, use_tpu=False)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_200.pt
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 411.220795
# Train Epoch: 1 [1280/2228 (56%)]	 pts_loss: 356.067261
# Valid: pts_loss: 833.647278
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 353.276367
# Train Epoch: 2 [1280/2228 (56%)]	 pts_loss: 407.580353
# Valid: pts_loss: 814.151801
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 433.282654
# Train Epoch: 3 [1280/2228 (56%)]	 pts_loss: 441.634155
# Valid: pts_loss: 869.833727
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 402.298187
# ...

# %%
# date: 3.19.2020 20:51 on TPU w RandomFlip RandomNoise RandomCrop
! cp /content/drive/'My Drive'/checkpoints/trained_resnet50_adam/detector_epoch_200.pt .
# !python mydector.py --seed 99722 --save-model --save-directory /content/drive/'My Drive'/checkpoints/trained_resnet50_adam5xLRw3R --batch-size 128 --alg adam --net resnet50 --lr 0.005 --epochs 201 --checkpoint
# Out:
# Namespace(alg='adam', angle=30, batch_size=128, checkpoint='', epochs=201, log_interval=10, loss='L2', lr=0.005, momentum=0.5, net='resnet50', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/trained_resnet50_adam5xLRw3R', save_interval=20, save_model=True, scheduler='', seed=99722, test_batch_size=64, use_tpu=False)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Traceback (most recent call last):
#   File "mydector.py", line 275, in <module>
#     print(main_test())
#   File "mydector.py", line 248, in main_test
#     train(args, train_loader, valid_loader, model, criterion_pts, optimizer, device)
#   File "mydector.py", line 62, in train
#     output_pts = model(input_img)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/myNN.py", line 277, in forward
#     return self._forward_impl(x)
# ...

# %%
# 10 times sgd lr date:3.18.2020
! cp /content/drive/'My Drive'/checkpoints/trained_resnet50_adam/detector_epoch_200.pt .
# !python mydector.py --seed 9922 --save-model --save-directory /content/drive/'My Drive'/checkpoints/trained_resnet50_adam_sgd --batch-size 128 --alg SGD --net resnet50 --lr 0.001 --epochs 101 --checkpoint detector_epoch_200.pt
# Out:
# Namespace(alg='SGD', angle=30, batch_size=128, checkpoint='detector_epoch_200.pt', epochs=101, log_interval=10, loss='L2', lr=0.001, momentum=0.5, net='resnet50', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/trained_resnet50_adam_sgd', save_interval=20, save_model=True, scheduler='', seed=9922, test_batch_size=64, use_tpu=False)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_200.pt
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 428.419708
# Valid: pts_loss: 927.593363
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 402.922546
# Train Epoch: 2 [1280/2228 (56%)]	 pts_loss: 448.919098
# Valid: pts_loss: 854.067919
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 446.350098
# Train Epoch: 3 [1280/2228 (56%)]	 pts_loss: 419.240509
# Valid: pts_loss: 969.672668
# ...
# Train Epoch: 4 [0/2228 (0%)]	 pts_loss: 419.061493
# Train Epoch: 4 [1280/2228 (56%)]	 pts_loss: 428.373993
# ...

# %%
! cp /content/drive/'My Drive'/checkpoints/10000trained_restnet18/detector_epoch_299.pt .
# !python mydector.py --seed 6199522 --save-model --save-directory /content/drive/'My Drive'/checkpoints/299_10000trained_restnet18_w_rotation --net resnet18 --lr 0.001 --checkpoint detector_epoch_299.pt --epoch 10000
# Out:
# Namespace(alg='SGD', angle=30, batch_size=64, checkpoint='detector_epoch_299.pt', epochs=10000, log_interval=20, lr=0.001, momentum=0.5, net='resnet18', no_cuda=False, num_class=42, phase='Train', roi=0.25, save_directory='/content/drive/My Drive/checkpoints/299_10000trained_restnet18_w_rotation', save_model=True, seed=6199522, test_batch_size=64)
# ===> Loading Datasets
# ===> Building Model
# ===> Start Training
# Training from checkpoint: detector_epoch_299.pt
# Train Epoch: 0 [0/2228 (0%)]	 pts_loss: 2657.366455
# Train Epoch: 0 [1280/2228 (57%)]	 pts_loss: 755.443054
# Valid: pts_loss: 889.133518
# ...
# Train Epoch: 1 [0/2228 (0%)]	 pts_loss: 656.369995
# Train Epoch: 1 [1280/2228 (57%)]	 pts_loss: 680.705444
# Valid: pts_loss: 624.442874
# ...
# Train Epoch: 2 [0/2228 (0%)]	 pts_loss: 484.670898
# Train Epoch: 2 [1280/2228 (57%)]	 pts_loss: 628.336121
# Valid: pts_loss: 667.158264
# ...
# Train Epoch: 3 [0/2228 (0%)]	 pts_loss: 597.620728
# ...
